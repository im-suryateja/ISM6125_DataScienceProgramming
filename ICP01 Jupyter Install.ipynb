# %% [markdown]
# # ICP01 Jupyter Install
# ## Surya Teja Pidakala

# %% [markdown]
# ![Passport Photo 2021.JPG](attachment:94807299-39c3-497b-9e40-f2050821adbe.JPG)
#
# ### Introduction
# I am Surya Teja currently persuing Master's in BAIS at University of South Florida. I am currently in my second semester. I am basically from India, born and raised there. I have completed all my education in Hyderbad. Also, i have worked for a multi-national company named Tata Consultancy Services for about 18 months before coming to fulfilling my dream of persuing masters at USF.

# %%
print('Hello World')
# Out:
# Hello World
